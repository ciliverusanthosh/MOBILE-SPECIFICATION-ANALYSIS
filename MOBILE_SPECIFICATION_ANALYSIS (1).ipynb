# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Mobile-Price.csv')
df
# Out:
#      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0        4.3   4.0  128.0         6.00           48       13.0           4000
# 1        3.4   6.0   64.0         4.50           48       12.0           4000
# 2        4.3   4.0    4.0         4.50           64       16.0           4000
# 3        4.4   6.0   64.0         6.40           48       15.0           3800
# 4        4.5   6.0  128.0         6.18           35       15.0           3800
# ..       ...   ...    ...          ...          ...        ...            ...
# 802      3.8   6.0   32.0         4.54           48       12.0           2800
# 803      4.1   8.0   64.0         4.54           64        8.0           2500
# 804      4.4   3.0   32.0         6.20           48        1.0           3800
# 805      3.7  10.0   32.0         4.50           64        8.0           3500
# 806      3.5   6.0   32.0         4.50           64       15.0           1050
#
#      Price
# 0    24999
# ...

# %%
df.describe()
# Out:
#           Ratings         RAM         ROM  Mobile_Size  Primary_Cam  \
# count  807.000000  807.000000  807.000000   807.000000   807.000000
# mean     4.112639    5.941760   64.390335     5.620660    47.821561
# std      0.367830    2.056359   53.868626     3.957409    11.155916
# min      2.800000    0.000000    2.000000     2.000000     5.000000
# 25%      3.900000    6.000000   32.000000     4.500000    48.000000
# 50%      4.100000    6.000000   32.000000     4.770000    48.000000
# 75%      4.400000    6.000000   64.000000     6.300000    48.000000
# max      4.800000   12.000000  256.000000    44.000000    64.000000
#
#         Selfi_Cam  Battery_Power          Price
# count  807.000000     807.000000     807.000000
# mean     8.868649    3278.859975   14269.167286
# std      4.547254     937.628801   23092.739983
# min      0.000000    1020.000000     479.000000
# 25%      8.000000    3000.000000     984.000000
# 50%      8.000000    3000.000000    1699.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        807 non-null    float64
#  1   RAM            807 non-null    float64
#  2   ROM            807 non-null    float64
#  3   Mobile_Size    807 non-null    float64
#  4   Primary_Cam    807 non-null    int64
#  5   Selfi_Cam      807 non-null    float64
#  6   Battery_Power  807 non-null    int64
#  7   Price          807 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 50.6 KB

# %% [markdown]
# DISTRIBUTION OF RAM SIZE UNDER  PRICE 20000

# %%
filtered_df = df[(df['Price'] >= 0) & (df['Price'] <= 20000)]

plt.scatter(filtered_df['Price'],filtered_df['RAM'])
plt.xlabel('Price')
plt.ylabel('RAM')
plt.title('Price vs RAM')
plt.show()

# %% [markdown]
# DISTRIBUTOIN OF BATTERY SIZE UNDER PRICE 20000

# %%
filtered_df = df[(df['Price'] >= 0) & (df['Price'] <= 20000)]
plt.figure(figsize=(10,5))
plt.scatter(filtered_df['Price'],filtered_df['Battery_Power'])
plt.xlabel('Price')
plt.ylabel('Battery_Power')
plt.title('Price vs Battery_Power')
plt.show()

# %%
df.columns
# Out:
# Index(['Ratings', 'RAM', 'ROM', 'Mobile_Size', 'Primary_Cam', 'Selfi_Cam',
#        'Battery_Power', 'Price'],
#       dtype='object')

# %%
filtered_df = df[(df['Price'] >= 0) & (df['Price'] <= 20000)]
ax = sns.histplot(filtered_df['Price'],kde=True,color='Skyblue')
ax.bar_label(ax.containers[0])
plt.show()

# %%
corr = df.corr()

# Generate a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='RAM', y='Price', data=df)
plt.xlabel('RAM')
plt.ylabel('Price')
plt.title('Box Plot of Price by RAM')
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x='ROM', y='Price', data=df)
plt.xlabel('ROM')
plt.ylabel('Price')
plt.title('Box Plot of Price by ROM')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='Price', y='Primary_Cam')
plt.xlabel('Price')
plt.ylabel('Primary Camera (MP)')
plt.title('Price vs Primary Camera')
plt.show()


plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='Price', y='Selfi_Cam')
plt.xlabel('Price')
plt.ylabel('Selfie Camera (MP)')
plt.title('Price vs Selfie Camera')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='Price', y='Mobile_Size')
plt.xlabel('Price')
plt.ylabel('Mobile Size')
plt.title('Price vs Mobile Size')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Ratings'], kde=True)
plt.xlabel('Ratings')
plt.title('Distribution of Ratings')
plt.show()

# %%
features = ['RAM', 'ROM', 'Mobile_Size', 'Battery_Power', 'Primary_Cam', 'Selfi_Cam']
for i in features:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(data=df, x='Price', y=i)
    plt.xlabel('Price')
    plt.ylabel(feature)
    plt.title(f'Price vs {feature}')
    plt.show()

# %%
sns.pairplot(df)
plt.show()
